# %%
a=10
print(a)
b=20
print(b)
# Out:
# 10
# 20

# %%
pip install numpy

# %%
import numpy as np

# %%
a=["divya","devi"]
type(a)
# Out:
# list

# %%
a=np.array([1,2,34,55,67])
type(a)
# Out:
# numpy.ndarray

# %%
b=np.array([5,7,3,6,7])
b
# Out:
# array([5, 7, 3, 6, 7])

# %%
a=10
print(a)
b=20
print(b)
# Out:
# 10
# 20

# %%
pip install numpy

# %%
import numpy as np

# %%
a=["divya","devi"]
type(a)
# Out:
# list

# %%
a=np.array([1,2,34,55,67])
type(a)
# Out:
# numpy.ndarray

# %%
b=np.array([5,7,3,6,7])
b
# Out:
# array([5, 7, 3, 6, 7])

# %%
a+b
# Out:
# array([ 6,  9, 37, 61, 74])

# %%
np.ndim(a)
# Out:
# 1

# %%
c=np.array([[1,2,3],[5,6,7]])
c
# Out:
# array([[1, 2, 3],
#        [5, 6, 7]])

# %%
np.ndim(c)
# Out:
# 2

# %%
d=np.arange(294,397)
d
# Out:
# array([294, 295, 296, 297, 298, 299, 300, 301, 302, 303, 304, 305, 306,
#        307, 308, 309, 310, 311, 312, 313, 314, 315, 316, 317, 318, 319,
#        320, 321, 322, 323, 324, 325, 326, 327, 328, 329, 330, 331, 332,
#        333, 334, 335, 336, 337, 338, 339, 340, 341, 342, 343, 344, 345,
#        346, 347, 348, 349, 350, 351, 352, 353, 354, 355, 356, 357, 358,
#        359, 360, 361, 362, 363, 364, 365, 366, 367, 368, 369, 370, 371,
#        372, 373, 374, 375, 376, 377, 378, 379, 380, 381, 382, 383, 384,
#        385, 386, 387, 388, 389, 390, 391, 392, 393, 394, 395, 396])

# %%
np.min(d)
# Out:
# np.int64(294)

# %%
np.max(d)
# Out:
# np.int64(396)

# %%
np.mean(d)
# Out:
# np.float64(345.0)

# %%
np.median(d)
# Out:
# np.float64(345.0)

# %%
import pandas as pd

# %%
d={'id':[1,2,3,4,5,6,7,8],"name":["divya","devi","mythili","motti","thiru","sakthi","kani","vinu"]}

# %%
d={'id':[1,2,3,4,5,6,7,8],"name":["divya","devi","mythili","motti","thiru","sakthi","kani","vinu"]}

# %%
df = pd.DataFrame(d)
display(df.head())
# Out:
#    id     name
# 0   1    divya
# 1   2     devi
# 2   3  mythili
# 3   4    motti
# 4   5    thiru
